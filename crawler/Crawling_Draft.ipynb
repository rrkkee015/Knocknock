# %%
from fake_headers import Headers as fh
from bs4 import BeautifulSoup as bs
from pprint import pprint as pp
import requests
import json
import time
import csv
import os

# %% [markdown]
# ### 가게크롤러

# %%
class StoreCrawler:
    __list_fields = ['id', 'name', 'businessCategory', 'category', 'subCategory', \
          'x', 'y', 'imageSrc',\
          'phone', 'routeUrl',\
          'roadAddr', 'commonAddr', 'addr',\
          'totalReviewCount', 'tags',\
          'options', 'priceCategory']
    __script_fields = ["description", "keywords", "themes", "microReviews", "menus", "businessHours", "relatedLinks", "gender", "ages", "contexts"]
    __total_fields = __list_fields + __script_fields
    __menu_id_to_category = {
        1 : "한식", 2 : "양식", 3 : "아시아음식", 4 : "일식", 5 : "중식", 6 : "분식", \
        7 : "뷔페", 8 : "카페", 9 : "기타"
    }
    
    def __init__(self):
        self.__store_ids = {}
        self.__store_list = []
        self.__store_cnt = 0
        
    
    ###############################################################################################################################
    def __make_base_url(self, menu_id, lx, ly):
        rx = lx + 0.0064034
        ry = ly + 0.0026665
        category = self.__menu_id_to_category[menu_id]
        base_url = "https://store.naver.com/sogum/api/businesses?bounds={};{};{};{}&menu={}&query=맛집&category={}&start=1&display=120&pageIndex=0"\
                    .format(lx, ly, rx, ry, menu_id, category)
        return base_url
    
    def __get_list_items(self, data, menu):
        store = { f: None for f in self.__list_fields }
        for field in self.__list_fields:
            if field in data:
                store[field] = data[field]
        store["subCategory"] = menu
        return store

    ###############################################################################################################################
    def __check_server(self, url):
        fake_header = fh(browser="chrome", os="win", headers=True).generate()
        res = requests.get(url, headers=fake_header)
        if str(res.status_code)[0] != "2":
            print("서버 에러, ", res.status_code)
            print(url)
            return False

        else:
            return bs(res.content, "html.parser")

    def __check(self, target, path):
        l = len(path)
        cnt = 0
        while cnt < l:
            if path[cnt] in target:
                if cnt == l-1:
                    target = target[path[cnt]]
                    cnt += 1
                    return True
                else:
                    if type(target[path[cnt]]) == type({1:1}):
                        target = target[path[cnt]]
                        cnt += 1
                    else:
                        return False                
            else:
                return False
    
    def __script_parser(self, script):
        script = script.text
        idx = 0
        start = end = -1
        while 1:
            if start == -1 and script[idx] == "=" and script[idx+2] == "{":
                start = idx+2
            if idx >= 1 and script[idx] == ";" and script[idx-1] == "}":
                end = idx
                break
            idx += 1

        return json.loads(script[start:end])
    
    def __script_crawler(self, store_id):
        base_url = "https://m.place.naver.com/restaurant/{}/home".format(store_id)
        soup = self.__check_server(base_url)
        if soup:
            script = soup.find_all("script")[2]
            data = self.__script_parser(script)
            return data
        else:
            print("script parsing disable")
            return None
    
    def __script_data_crawler(self, data):
    
        root_query = {}
        if self.__check(data, ["ROOT_QUERY"]):
            root_query = data["ROOT_QUERY"]

        restaurant = {}
        for key in root_query.keys(): 
            if key.startswith("restaurant"):
                if self.__check(data, ["$ROOT_QUERY." + key]):
                    restaurant = data["$ROOT_QUERY." + key ]

        # Base 크롤링
        RestaurantBase = {}
        if self.__check(restaurant, ["base", "id"]):
            RestaurantBase = data[restaurant["base"]["id"]]

        ## description
        description = None
        if self.__check(RestaurantBase, ["description"]):
            description = RestaurantBase["description"]

        ## keywords
        keywords = None
        if self.__check(RestaurantBase, ["keywords", "json"]):
            keywords = RestaurantBase["keywords"]["json"]

        ## themes
        themes = None
        if self.__check(RestaurantBase, ["themes", "json"]):
            themes = RestaurantBase["themes"]["json"]

        ## microReviews
        microReviews = None
        if self.__check(RestaurantBase, ["microReviews", "json"]):
            microReviews = RestaurantBase["microReviews"]["json"]

        ## relatedLinks
        relatedLinks = None
        relatedLinks_fields = ["name", "url"]
        if self.__check(RestaurantBase, ["relatedLinks"]) and RestaurantBase["relatedLinks"]:
            relatedLinks = []
            for relatedLink_data in RestaurantBase["relatedLinks"]:
                relatedLink = { f: None for f in relatedLinks_fields }
                if self.__check(relatedLink_data, ["id"]):
                    relatedLink_d = data[relatedLink_data["id"]]
                    for field in relatedLinks_fields:
                        if self.__check(relatedLink_d, [field]):
                            relatedLink[field] = relatedLink_d[field]
                    relatedLinks.append(relatedLink)

        ## businessHours    
        businessHours = None
        businessHours_fields = ["day", "isDayOff", "startTime", "endTime", "description"]
        if self.__check(RestaurantBase, ["businessHours"]) and RestaurantBase["businessHours"]:
            businessHours = []
            for businessHour_data in RestaurantBase["businessHours"]:
                businessHour = { f: None for f in businessHours_fields }
                if self.__check(businessHour_data, ["id"]):
                    businessHour_d = data[businessHour_data["id"]]
                    for field in businessHours_fields:
                        if self.__check(businessHour_d, [field]):
                            businessHour[field] = businessHour_d[field]
                    businessHours.append(businessHour)  

        ## menus
        menus = None
        menus_fields = ["name", "description", "price", "priceType", "change", "images"]
        if self.__check(RestaurantBase, ["menus"]) and RestaurantBase["menus"]:
            menus = []
            for menu_data in RestaurantBase["menus"]:
                menu = { f: None for f in menus_fields }
                if self.__check(menu_data, ["id"]):
                    menu_d = data[menu_data["id"]]
                    for field in menus_fields:
                        if field == "images" and self.__check(menu_d, ["images", "json"]):
                            menu["images"] = menu_d["images"]["json"] 
                        elif self.__check(menu_d, [field]):
                            menu[field] = menu_d[field]
                    menus.append(menu)

        

        # BusinessStats 크롤링
        BusinessStats= {}
        if self.__check(restaurant, ["businessStats", "id"]):
            BusinessStats = data[restaurant["businessStats"]["id"]]

        ## gender
        gender = None
        if self.__check(BusinessStats, ["gender", "id"]):    
            gender = {"f" : data[BusinessStats["gender"]["id"]]["f"], "m" : data[BusinessStats["gender"]["id"]]["m"]}

        ## age
        ages = None
        ages_fields = ["ageKey", "value", "rank"]
        if self.__check(BusinessStats, ["age"]) and BusinessStats["age"]:
            ages = []
            for age_data in BusinessStats["age"]:
                age = { f: None for f in ages_fields }
                if self.__check(age_data, ["id"]):
                    age_d = data[age_data["id"]]
                    for field in ages_fields:
                        if self.__check(age_d, [field]):
                            age[field] = age_d[field]
                    ages.append(age)

        ## contexts
        contexts = None
        contexts_fields = ["name", "keywords"]
        if self.__check(BusinessStats, ["contexts"]) and BusinessStats["contexts"]:
            contexts = []
            for context_data in BusinessStats["contexts"]:
                context = { f: None for f in contexts_fields }
                if self.__check(context_data, ["id"]):
                    context_d = data[context_data["id"]]
                    for field in contexts_fields:
                        if field == "keywords" and self.__check(context_d, ["keywords", "json"]):
                            context["keywords"] = context_d["keywords"]["json"]
                        elif self.__check(context_d, [field]):
                            context[field] = context_d[field]
                    contexts.append(context)

        result = {
            "description": description,
            "keywords": keywords,
            "themes": themes,
            "microReviews": microReviews,
            "menus": menus,
            "businessHours": businessHours,
            "relatedLinks": relatedLinks,
            "gender": gender,
            "ages": ages,
            "contexts": contexts
        }
        return result
    
    
    ###############################################################################################################################

    def __save_to_csv(self):
        print("save, ", self.__store_cnt)
        fileName = "store"
        if self.filename:
            fileName += "_" + str(self.filename)

        if self.__store_cnt == self.savepoint:    
            with open(fileName + ".csv", "w", newline="", encoding="utf8") as f:
                dictwriter = csv.DictWriter(f, fieldnames = self.__total_fields)
                dictwriter.writeheader()
                for store in self.__store_list:
                    dictwriter.writerow(store)
        else:
            with open(fileName + ".csv", "a", newline="", encoding="utf8") as f:
                for store in self.__store_list: 
                    dictwriter = csv.DictWriter(f, fieldnames = self.__total_fields)
                    dictwriter.writerow(store)

    
    def __error_handling(self):
        for store in self.__error_stores:
            time.sleep(5)
            store.update(self.__crawling_script(store["id"]))
        pp(self.__error_stores)
        
        with open("store_{}.csv".format(self.filename), "a", newline="", encoding="utf8") as f:
            for store in self.__error_stores:
                dictwriter = csv.DictWriter(f, fieldnames = self.__total_fields)
                dictwriter.writerow(store)

    def __crawling_script(self, store_id):
        data = self.__script_crawler(store_id)
        if data:
            return self.__script_data_crawler(data)
        else:
            return {}
        
    
    def __crawling_area(self, menu_id, x, y):
        base_url = self.__make_base_url(menu_id, x, y)
        fake_header = fh(browser="chrome", os="win", headers=True).generate()
        res = requests.get(base_url, headers=fake_header)
        if str(res.status_code)[0] == "5":
            time.sleep(5)
            res = requests.get(base_url, headers=fake_header)
            pp(res)
        res = res.json()["items"]
        for data in res:
            time.sleep(1)
            store = self.__get_list_items(data, self.__menu_id_to_category[menu_id])
            if not self.__store_ids.get(store["id"]) and self.lx <= float(store["x"]) < self.rx and self.ly <= float(store["y"]) < self.ry:
                detail_data = self.__crawling_script(store["id"])
                if detail_data == {}:
                    self.__error_stores.append(store)
                    self.__store_ids[store["id"]] = 1
                    self.__store_cnt += 1
                else:
                    store.update(detail_data)
                    self.__store_list.append(store)
                    self.__store_ids[store["id"]] = 1
                    self.__store_cnt += 1
                
                #save
                if not self.__store_cnt % self.savepoint:
                    self.__save_to_csv()
                    # clear
                    self.__store_list = []
                
                #check
                if self.breakpoint > 0 and self.__store_cnt >= self.breakpoint:
                    if len(self.__store_list) < self.savepoint:
                        self.__save_to_csv()
                    return True
    
    # 입력 받을 때, breakpoint > savepoint 여야만함.
    def start_crawling(self, lx, ly, rx, ry, breakpoint=-1, savepoint=100, filename=None):
        self.lx = lx
        self.ly = ly
        self.rx = rx
        self.ry = ry
        self.breakpoint = breakpoint
        self.savepoint = savepoint
        self.filename = filename
        self.__error_stores = []
        
        dx = 0.0064034
        dy = 0.0026665
        n = 10000000000
        cnt = 0
        for x in range(int(lx*n), int(rx*n), int(dx*n)):
            for y in range(int(ly*n), int(ry*n), int(dy*n)):
                print(round(x/n, 8), round(y/n, 8))
                for menu_id in range(1,10):
                    if self.__crawling_area(menu_id, round(x/n, 8), round(y/n, 8)):
                        print("총 {}개의 가게 크롤링 완료, {}개의 디테일 페이지 크롤링 실패".format(self.__store_cnt, len(self.__error_stores)))
                        self.__error_handling()
                        return
        # 마지막 저장 체크
        if len(self.__store_list) < self.savepoint:
            self.__save_to_csv()
        
        print("총 {}개의 가게 크롤링 완료, {}개의 디테일 페이지 크롤링 실패".format(self.__store_cnt, len(self.__error_stores)))
        self.__error_handling()

# %% [markdown]
# ##### test

# %%
# %%time
# GN_lx = 127.0085783 
# GN_ly = 37.4549044
# GN_rx = 127.1251034 
# GN_ry = 37.5358413
# GN_cx = 127.0475020 
# GN_cy = 37.5173050
# breakpoint = 105
# savepoint = 100
# filename = "test"


# test_crawler = StoreCrawler()
# test_crawler.start_crawling(GN_cx, GN_cy, GN_rx, GN_ry, breakpoint, savepoint, filename)

# %% [markdown]
# ### 구역 나누기

# %%
seoul = {
    "name": "서울특별시",
    "x": 126.9783880,
    "y": 37.5666100,
    "lx": 126.7644840,
    "ly": 37.4282975,
    "rx": 127.1837949,
    "ry": 37.7014553,
}

# %%
sections = []
dx = round(seoul["rx"] - seoul["lx"], 7)
dy = round(seoul["ry"] - seoul["ly"], 7)

ddx = round(dx/6, 7)
ddy = round(dy/4, 7)

startx = seoul["lx"]
starty = seoul["ly"]
for n in range(6):
    for m in range(4):
        section = {}
        section["lx"] = round(startx + ddx*n, 7)
        section["ly"] = round(starty + ddy*m, 7)
        section["rx"] = round(section["lx"] + ddx, 7)
        section["ry"] = round(section["ly"] + ddy, 7)
        sections.append(section)
pp(sections)
# Out:
# [{'lx': 126.764484, 'ly': 37.4282975, 'rx': 126.8343691, 'ry': 37.496587},
#  {'lx': 126.764484, 'ly': 37.496587, 'rx': 126.8343691, 'ry': 37.5648765},
#  {'lx': 126.764484, 'ly': 37.5648765, 'rx': 126.8343691, 'ry': 37.633166},
#  {'lx': 126.764484, 'ly': 37.633166, 'rx': 126.8343691, 'ry': 37.7014555},
#  {'lx': 126.8343691, 'ly': 37.4282975, 'rx': 126.9042542, 'ry': 37.496587},
#  {'lx': 126.8343691, 'ly': 37.496587, 'rx': 126.9042542, 'ry': 37.5648765},
#  {'lx': 126.8343691, 'ly': 37.5648765, 'rx': 126.9042542, 'ry': 37.633166},
#  {'lx': 126.8343691, 'ly': 37.633166, 'rx': 126.9042542, 'ry': 37.7014555},
#  {'lx': 126.9042542, 'ly': 37.4282975, 'rx': 126.9741393, 'ry': 37.496587},
#  {'lx': 126.9042542, 'ly': 37.496587, 'rx': 126.9741393, 'ry': 37.5648765},
#  {'lx': 126.9042542, 'ly': 37.5648765, 'rx': 126.9741393, 'ry': 37.633166},
#  {'lx': 126.9042542, 'ly': 37.633166, 'rx': 126.9741393, 'ry': 37.7014555},
#  {'lx': 126.9741393, 'ly': 37.4282975, 'rx': 127.0440244, 'ry': 37.496587},
#  {'lx': 126.9741393, 'ly': 37.496587, 'rx': 127.0440244, 'ry': 37.5648765},
#  {'lx': 126.9741393, 'ly': 37.5648765, 'rx': 127.0440244, 'ry': 37.633166},
#  {'lx': 126.9741393, 'ly': 37.633166, 'rx': 127.0440244, 'ry': 37.7014555},
#  {'lx': 127.0440244, 'ly': 37.4282975, 'rx': 127.1139095, 'ry': 37.496587},
#  {'lx': 127.0440244, 'ly': 37.496587, 'rx': 127.1139095, 'ry': 37.5648765},
#  {'lx': 127.0440244, 'ly': 37.5648765, 'rx': 127.1139095, 'ry': 37.633166},
#  {'lx': 127.0440244, 'ly': 37.633166, 'rx': 127.1139095, 'ry': 37.7014555},
#  {'lx': 127.1139095, 'ly': 37.4282975, 'rx': 127.1837946, 'ry': 37.496587},
#  {'lx': 127.1139095, 'ly': 37.496587, 'rx': 127.1837946, 'ry': 37.5648765},
#  {'lx': 127.1139095, 'ly': 37.5648765, 'rx': 127.1837946, 'ry': 37.633166},
#  {'lx': 127.1139095, 'ly': 37.633166, 'rx': 127.1837946, 'ry': 37.7014555}]

# %%
def total_checker(sections):
    idx = 0
    for section in sections:
        url = "https://store.naver.com/sogum/api/businesses?bounds={};{};{};{}&query=맛집&start=1&display=120&pageIndex=0".format(
        section["lx"], section["ly"], section["rx"], section["ry"])
        print("section ", idx)
        print(url)
        idx += 1

# %%
total_checker(sections)
# Out:
# section  0
# https://store.naver.com/sogum/api/businesses?bounds=126.764484;37.4282975;126.8343691;37.496587&query=맛집&start=1&display=120&pageIndex=0
# section  1
# https://store.naver.com/sogum/api/businesses?bounds=126.764484;37.496587;126.8343691;37.5648765&query=맛집&start=1&display=120&pageIndex=0
# section  2
# https://store.naver.com/sogum/api/businesses?bounds=126.764484;37.5648765;126.8343691;37.633166&query=맛집&start=1&display=120&pageIndex=0
# section  3
# https://store.naver.com/sogum/api/businesses?bounds=126.764484;37.633166;126.8343691;37.7014555&query=맛집&start=1&display=120&pageIndex=0
# section  4
# https://store.naver.com/sogum/api/businesses?bounds=126.8343691;37.4282975;126.9042542;37.496587&query=맛집&start=1&display=120&pageIndex=0
# section  5
# https://store.naver.com/sogum/api/businesses?bounds=126.8343691;37.496587;126.9042542;37.5648765&query=맛집&start=1&display=120&pageIndex=0
# section  6
# https://store.naver.com/sogum/api/businesses?bounds=126.8343691;37.5648765;126.9042542;37.633166&query=맛집&start=1&display=120&pageIndex=0
# section  7
# https://store.naver.com/sogum/api/businesses?bounds=126.8343691;37.633166;126.9042542;37.7014555&query=맛집&start=1&display=120&pageIndex=0
# section  8
# https://store.naver.com/sogum/api/businesses?bounds=126.9042542;37.4282975;126.9741393;37.496587&query=맛집&start=1&display=120&pageIndex=0
# section  9
# https://store.naver.com/sogum/api/businesses?bounds=126.9042542;37.496587;126.9741393;37.5648765&query=맛집&start=1&display=120&pageIndex=0
# section  10
# https://store.naver.com/sogum/api/businesses?bounds=126.9042542;37.5648765;126.9741393;37.633166&query=맛집&start=1&display=120&pageIndex=0
# section  11
# https://store.naver.com/sogum/api/businesses?bounds=126.9042542;37.633166;126.9741393;37.7014555&query=맛집&start=1&display=120&pageIndex=0
# section  12
# https://store.naver.com/sogum/api/businesses?bounds=126.9741393;37.4282975;127.0440244;37.496587&query=맛집&start=1&display=120&pageIndex=0
# section  13
# https://store.naver.com/sogum/api/businesses?bounds=126.9741393;37.496587;127.0440244;37.5648765&query=맛집&start=1&display=120&pageIndex=0
# section  14
# https://store.naver.com/sogum/api/businesses?bounds=126.9741393;37.5648765;127.0440244;37.633166&query=맛집&start=1&display=120&pageIndex=0
# section  15
# https://store.naver.com/sogum/api/businesses?bounds=126.9741393;37.633166;127.0440244;37.7014555&query=맛집&start=1&display=120&pageIndex=0
# section  16
# https://store.naver.com/sogum/api/businesses?bounds=127.0440244;37.4282975;127.1139095;37.496587&query=맛집&start=1&display=120&pageIndex=0
# section  17
# https://store.naver.com/sogum/api/businesses?bounds=127.0440244;37.496587;127.1139095;37.5648765&query=맛집&start=1&display=120&pageIndex=0
# section  18
# https://store.naver.com/sogum/api/businesses?bounds=127.0440244;37.5648765;127.1139095;37.633166&query=맛집&start=1&display=120&pageIndex=0
# section  19
# https://store.naver.com/sogum/api/businesses?bounds=127.0440244;37.633166;127.1139095;37.7014555&query=맛집&start=1&display=120&pageIndex=0
# section  20
# https://store.naver.com/sogum/api/businesses?bounds=127.1139095;37.4282975;127.1837946;37.496587&query=맛집&start=1&display=120&pageIndex=0
# section  21
# https://store.naver.com/sogum/api/businesses?bounds=127.1139095;37.496587;127.1837946;37.5648765&query=맛집&start=1&display=120&pageIndex=0
# section  22
# https://store.naver.com/sogum/api/businesses?bounds=127.1139095;37.5648765;127.1837946;37.633166&query=맛집&start=1&display=120&pageIndex=0
# section  23
# https://store.naver.com/sogum/api/businesses?bounds=127.1139095;37.633166;127.1837946;37.7014555&query=맛집&start=1&display=120&pageIndex=0

# %% [markdown]
# ##### 크롤링ㄱㄱ

# %%
def go_crawling(section_id):
    ts = sections[section_id] # target section
    StoreCrawler().start_crawling(ts["lx"], ts["ly"], ts["rx"], ts["ry"], breakpoint=-1, savepoint=100, filename="section{}".format(section_id))

# %%
go_crawling(9)
# Out:
# 126.9042542 37.496587
# 126.9042542 37.4992535
# 126.9042542 37.50192
# save,  100
# 126.9042542 37.5045865
# save,  200
# 126.9042542 37.507253
# 126.9042542 37.5099195
# 126.9042542 37.512586
# save,  300
# 126.9042542 37.5152525
# save,  400
# save,  500
# save,  600
# save,  700
# 126.9042542 37.517919
# save,  800
# save,  900
# 126.9042542 37.5205855
# save,  1000
# 126.9042542 37.523252
# save,  1100
# 126.9042542 37.5259185
# save,  1200
# 126.9042542 37.528585
# 126.9042542 37.5312515
# 126.9042542 37.533918
# 126.9042542 37.5365845
# 126.9042542 37.539251
# 126.9042542 37.5419175
# 126.9042542 37.544584
# 126.9042542 37.5472505
# save,  1300
# 126.9042542 37.549917
# save,  1400
# 126.9042542 37.5525835
# save,  1500
# save,  1600
# save,  18600
# 126.9682882 37.539251
# save,  18700
# 126.9682882 37.5419175
# save,  18800
# save,  18900
# save,  19000
# 126.9682882 37.544584
# save,  19100
# 126.9682882 37.5472505
# 126.9682882 37.549917
# save,  19200
# 126.9682882 37.5525835
# save,  19300
# 126.9682882 37.55525
# save,  19400
# 126.9682882 37.5579165
# save,  19500
# 126.9682882 37.560583
# save,  19600
# save,  19700
# 126.9682882 37.5632495
# save,  19780
# 총 19780개의 가게 크롤링 완료, 5개의 디테일 페이지 크롤링 실패
# [{'addr': '영등포동7가 66-4',
#   'ages': None,
#   'businessCategory': 'restaurant',
#   'businessHours': [{'day': '매일',
#                      'description': '',
#                      'endTime': '23:00',
#                      'isDayOff': False,
#                      'startTime': '11:00'}],
#   'category': '한식',
#   'commonAddr': '서울 영등포구',
#   'contexts': None,
#   'description': '[휴무일] 연중무휴\r\n'
#                  '\r\n'
#                  '[영업시간] 오전11:00 ~ 오후23:00까지 연중무휴\r\n'
#                  '\r\n'
#                  '\r\n'
#                  '\r\n'
#                  '\r\n'
#                  '안녕하세요.\r\n'
#                  '\r\n'
#                  '영등포구 영등포동7가 에 위치한 명태이야기 입니다.\r\n'
#                  '\r\n'
#                  '저희 업소는 참기름도 직접 짜서 최상의 재료로 양념 소스를 만들어 사용하므로 \r\n'
#                  '\r\n'
#                  '명태와 함께드시면 깊은맛과 건강을 챙길수있읍니다.\r\n'
#                  '\r\n'
#                  '항상 좋은 맛과 친절함을 드리기 위해 많은 노력을 하고 있습니다.\r\n'
#                  '\r\n'
#                  '앞으로도 고객님들의 관심과 사랑에 보답하기 위해\r\n'
#                  '\r\n'
#                  '더 좋은 맛과 서비스를 제공해드릴 것을 약속드리며\r\n'
#                  '\r\n'
#                  '최상의 맛과 친절함을 드리는 명태이야기가 되겠습니다.',
#   'gender': None,
#   'id': '38548367',
#   'imageSrc': 'http://ldb.phinf.naver.net/20160912_87/1473663862035wj5gc_JPEG/176862563441383_0.jpeg',
#   'keywords': ['명태찜', '코다리찜', '생대구탕', '황태해장국'],
#   'menus': [{'change': False,
#              'description': None,
#              'images': [],
#              'name': '매콤명태찜정식',
#              'price': '9000',
#              'priceType': None},
#             {'change': False,
#              'description': None,
#              'images': [],
#              'name': '생대구탕',
#              'price': '10000',
#              'priceType': None},
#             {'change': False,
#              'description': None,
#              'images': [],
#              'name': '고등어구이',
#              'price': '8000',
#              'priceType': None},
#             {'change': False,
#              'description': None,
#              'images': [],
#              'name': '황태해장국',
#              'price': '7000',
#              'priceType': None},
#             {'change': False,
#              'description': None,
#              'images': [],
#              'name': '여름별미 물회',
#              'price': '10000',
#              'priceType': None},
#             {'change': False,
#              'description': None,
#              'images': [],
#              'name': '매콤명태찜 소',
#              'price': '25000',
#              'priceType': None},
#             {'change': False,
#              'description': None,
#              'images': [],
#              'name': '매콤명태찜 중',
#              'price': '35000',
#              'priceType': None},
#             {'change': False,
#              'description': None,
#              'images': [],
#              'name': '매콤명태찜 대',
#              'price': '45000',
#              'priceType': None},
#             {'change': False,
#              'description': None,
#              'images': [],
#              'name': '통문어명태찜',
#              'price': '58000',
#              'priceType': None},
#             {'change': False,
#              'description': None,
#              'images': [],
#              'name': '통갑오징어명태찜',
#              'price': '55000',
#              'priceType': None},
#             {'change': False,
#              'description': None,
#              'images': [],
#              'name': '갑오정어숙회',
#              'price': '25000',
#              'priceType': None}],
#   'microReviews': None,
#   'name': '명태이야기',
#   'options': '포장,배달',
#   'phone': '0508-5196-1379',
#   'priceCategory': '2만원 대',
#   'relatedLinks': [{'name': '망고플레이트',
#                     'url': 'https://www.mangoplate.com/restaurants/9xbUJTmFSlln'},
#                    {'name': '식신', 'url': 'https://www.siksinhot.com/P/810759'},
#                    {'name': '다이닝코드',
#                     'url': 'https://diningcode.com/profile.php?rid=DFxL92uYYiNA'}],
#   'roadAddr': '서울 영등포구 국회대로46길 3',
#   'routeUrl': 'http://m.map.naver.com/viewer/route.nhn?ename=%EB%AA%85%ED%83%9C%EC%9D%B4%EC%95%BC%EA%B8%B0&ex=126.9048418&ey=37.5252947&edid=38548367',
#   'subCategory': '한식',
#   'tags': None,
#   'themes': ['젊고 캐쥬얼한', '아이와 함께'],
#   'totalReviewCount': '10',
#   'x': '126.9048418',
#   'y': '37.5252947'},
#  {'addr': '동교동 161-4',
#   'ages': None,
#   'businessCategory': 'bar',
#   'businessHours': [{'day': '매일',
#                      'description': '',
#                      'endTime': '02:30',
#                      'isDayOff': False,
#                      'startTime': '16:00'}],
#   'category': '맥주,호프',
#   'commonAddr': '서울 마포구',
#   'contexts': None,
#   'description': '여느 다른 술집과 차별화된 모습을 보여드리겠습니다. 언제나 신선한 재료를 사용하여 제일 중요한 음식의 맛을 '
#                  '기본으로 다양한 술과 좋은 분위기, 음악 등 최고의 서비스를 제공하겠습니다. 오시는 모든 분들께 제 가족을 '
#                  '향한 마음을 담아내겠습니다. 저희 스테이를 이용해주신 여러분들께, 앞으로 오실 모든 분들께 감사의 인삿말을 '
#                  '올리겠습니다. 저희 스테이에서 행복한 기억들만 안고 가실 수 있도록 항상 생각하고 힘쓰겠습니다.',
#   'gender': None,
#   'id': '1824559012',
#   'imageSrc': 'http://ldb.phinf.naver.net/20191004_263/15701277723360yki1_JPEG/urrarfC-YpNnFoYqeDqPn4xo.jpg',
#   'keywords': ['맥주', '홍대', '술집', '단체'],
#   'menus': [{'change': False,
#              'description': None,
#              'images': ['http://ldb.phinf.naver.net/20191004_230/1570123527702A5eU6_JPEG/fnjWREdJDiD_sy2hS4nptJj8.jpg'],
#              'name': '칠리왕새우샐러드',
#              'price': '19000',
#              'priceType': None},
#             {'change': False,
#              'description': None,
#              'images': ['http://ldb.phinf.naver.net/20191004_248/1570123734562izJmj_JPEG/-tX-TAOdhXf9YlhQwRSHS6i8.jpg'],
#              'name': '모듬 소세지',
#              'price': '18000',
#              'priceType': None},
#             {'change': False,
#              'description': None,
#              'images': ['http://ldb.phinf.naver.net/20191004_81/1570123754033A0xoc_JPEG/4Xu9SQsIWHutnNHzEUk9v_ae.jpg'],
#              'name': '버팔로 윙+프렌치 프라이',
#              'price': '17000',
#              'priceType': None},
#             {'change': False,
#              'description': None,
#              'images': ['http://ldb.phinf.naver.net/20191004_128/1570123780218GDgq6_JPEG/C5JFwFPfwF04IVwFY9jgoah1.jpg'],
#              'name': '치즈 플래터',
#              'price': '19000',
#              'priceType': None},
#             {'change': False,
#              'description': None,
#              'images': ['http://ldb.phinf.naver.net/20191004_83/15701237952381yU8i_JPEG/UdUdZkeX8afoqV21DMm8reA_.jpg'],
#              'name': '고르곤졸라 피자',
#              'price': '14000',
#              'priceType': None},
#             {'change': False,
#              'description': None,
#              'images': ['http://ldb.phinf.naver.net/20191004_130/1570123825754MAls4_JPEG/zn19jV75YkprK8sd_LrKsBWU.jpg'],
#              'name': '모듬 마른안주',
#              'price': '18000',
#              'priceType': None},
#             {'change': False,
#              'description': None,
#              'images': [],
#              'name': '계절 과일',
#              'price': '25000',
#              'priceType': None},
#             {'change': True,
#              'description': None,
#              'images': [],
#              'name': '세계맥주 일절 ',
#              'price': '',
#              'priceType': None},
#             {'change': False,
#              'description': None,
#              'images': ['http://ldb.phinf.naver.net/20191013_300/1570905493365OmES0_JPEG/oBKQckzo3CGsz7BHjTLIlKYG.jpg'],
#              'name': '골뱅이 무침',
#              'price': '18000',
#              'priceType': None}],
#   'microReviews': None,
#   'name': '스테이',
#   'options': '예약,주차,포장,남/녀 화장실 구분,단체석,무선 인터넷,반려동물 동반',
#   'phone': '02-323-9343',
#   'priceCategory': '2만원 대',
#   'relatedLinks': [{'name': '망고플레이트',
#                     'url': 'https://www.mangoplate.com/restaurants/q_ZOJoswvm'}],
#   'roadAddr': '서울 마포구 동교로 176 청휘빌딩 1층',
#   'routeUrl': 'http://m.map.naver.com/viewer/route.nhn?ename=%EC%8A%A4%ED%85%8C%EC%9D%B4&ex=126.9216861&ey=37.5561738&edid=1824559012',
#   'subCategory': '기타',
#   'tags': None,
#   'themes': ['데이트하기 좋은', '젊고 캐쥬얼한', '모임하기 좋은'],
#   'totalReviewCount': '0',
#   'x': '126.9216861',
#   'y': '37.5561738'},
#  {'addr': '서교동 449-43',
#   'ages': None,
#   'businessCategory': 'restaurant',
#   'businessHours': [{'day': '매일',
#                      'description': '',
#                      'endTime': '01:00',
#                      'isDayOff': False,
#                      'startTime': '11:30'}],
#   'category': '치킨,닭강정',
#   'commonAddr': '서울 마포구',
#   'contexts': [{'keywords': ['치킨', '순대국밥'], 'name': '인기토픽'}],
#   'description': '★ 배달지역 : 서교동,연남동,동교동,성산1동 ★\r\n'
#                  '\r\n'
#                  '반갑습니다.\r\n'
#                  '항상 고객님에게 최고의 맛을 제공하기 위해 끊임없이 노력하고 있습니다.\r\n'
#                  '\r\n'
#                  '끊임없는 노력과 다양한 요리연구를 통해 새롭고 차별화된 메뉴를 제공함으로써 브랜드의 가치를 극대화하고\r\n'
#                  ' 있으며 이를 통한 고객만족을 최우선으로 생각합니다.\r\n'
#                  '앞으로도 고객님들의 변함 없는 관심과 사랑에 보답하기 위해 더 좋은 맛과 서비스를 제공하기 위해 '
#                  '노력하며\r\n'
#                  ' 고객님의 건강과 행복을 책임진다는 사명감을 갖고 더욱더 발전해 나아가도록 노력 하겠습니다.\r\n'
#                  '또한 모든 메뉴에서 타업체와 동일한 맛이 아닌 차별화된 맛과 품질로 보답해 드리겠습니다.\r\n'
#                  '\r\n'
#                  'BBQ 서교점 임직원 일동',
#   'gender': None,
#   'id': '33167007',
#   'imageSrc': 'http://ldb.phinf.naver.net/20161025_246/1477375280373f9TIt_JPEG/176975553140196_0.jpeg',
#   'keywords': ['황금올리브치킨', '통다리바베큐', '황금올리브반반', '황금올리브속안심', '황금올리브핫윙'],
#   'menus': [{'change': False,
#              'description': None,
#              'images': [],
#              'name': '황금올리브 반반',
#              'price': '17000',
#              'priceType': None},
#             {'change': False,
#              'description': None,
#              'images': [],
#              'name': '자메이카 통다리구이',
#              'price': '17500',
#              'priceType': None},
#             {'change': False,
#              'description': None,
#              'images': [],
#              'name': '꼬꼬넛 치킨',
#              'price': '21000',
#              'priceType': None},
#             {'change': False,
#              'description': None,
#              'images': [],
#              'name': '황금올리브치킨',
#              'price': '16000',
#              'priceType': None},
#             {'change': False,
#              'description': None,
#              'images': [],
#              'name': '시크릿양념치킨',
#              'price': '17000',
#              'priceType': None},
#             {'change': False,
#              'description': None,
#              'images': [],
#              'name': '황금올리브 닭다리',
#              'price': '17500',
#              'priceType': None},
#             {'change': False,
#              'description': None,
#              'images': [],
#              'name': '매운 황금올리브 닭다리',
#              'price': '19000',
#              'priceType': None},
#             {'change': False,
#              'description': None,
#              'images': [],
#              'name': '황금올리브 닭다리 반반',
#              'price': '18500',
#              'priceType': None},
#             {'change': False,
#              'description': None,
#              'images': [],
#              'name': '마라 핫 치킨(한마리,윙)',
#              'price': '18900',
#              'priceType': None},
#             {'change': False,
#              'description': None,
#              'images': [],
#              'name': '통살 마라 핫 치킨',
#              'price': '20900',
#              'priceType': None},
#             {'change': False,
#              'description': None,
#              'images': [],
#              'name': '황금올리브속안심',
#              'price': '17000',
#              'priceType': None},
#             {'change': False,
#              'description': None,
#              'images': [],
#              'name': '통살크래커',
#              'price': '18000',
#              'priceType': None},
#             {'change': False,
#              'description': None,
#              'images': [],
#              'name': '바삭칸치킨',
#              'price': '16000',
#              'priceType': None},
#             {'change': False,
#              'description': None,
#              'images': [],
#              'name': '통살 바삭칸치킨',
#              'price': '17900',
#              'priceType': None},
#             {'change': False,
#              'description': None,
#              'images': [],
#              'name': '황금올리브 핫 윙',
#              'price': '18000',
#              'priceType': None},
#             {'change': False,
#              'description': None,
#              'images': [],
#              'name': '치즐링',
#              'price': '19000',
#              'priceType': None},
#             {'change': False,
#              'description': None,
#              'images': [],
#              'name': '통살 치즐링',
#              'price': '19900',
#              'priceType': None},
#             {'change': False,
#              'description': None,
#              'images': [],
#              'name': '허니갈릭스(한마리,윙)',
#              'price': '18900',
#              'priceType': None},
#             {'change': False,
#              'description': None,
#              'images': [],
#              'name': '소이갈릭스(한마리,윙)',
#              'price': '18900',
#              'priceType': None},
#             {'change': False,
#              'description': None,
#              'images': [],
#              'name': '빠리치킨(한마리,윙)',
#              'price': '19000',
#              'priceType': None},
#             {'change': False,
#              'description': None,
#              'images': [],
#              'name': '치킨강정',
#              'price': '18000',
#              'priceType': None},
#             {'change': False,
#              'description': None,
#              'images': [],
#              'name': '통살강정',
#              'price': '19000',
#              'priceType': None},
#             {'change': False,
#              'description': None,
#              'images': [],
#              'name': '스모크치킨',
#              'price': '17000',
#              'priceType': None},
#             {'change': False,
#              'description': None,
#              'images': [],
#              'name': '매달구',
#              'price': '19500',
#              'priceType': None},
#             {'change': False,
#              'description': None,
#              'images': [],
#              'name': '파닭의 꿈(통살)',
#              'price': '19000',
#              'priceType': None},
#             {'change': False,
#              'description': None,
#              'images': [],
#              'name': '양파의 청춘(통살)',
#              'price': '19000',
#              'priceType': None}],
#   'microReviews': None,
#   'name': 'BBQ서교점',
#   'options': '예약,포장,배달',
#   'phone': '02-322-6677',
#   'priceCategory': '5만원 대',
#   'relatedLinks': [{'name': '망고플레이트',
#                     'url': 'https://www.mangoplate.com/restaurants/5nDYOZlZio'}],
#   'roadAddr': '서울 마포구 월드컵북로5길 22',
#   'routeUrl': 'http://m.map.naver.com/viewer/route.nhn?ename=BBQ%EC%84%9C%EA%B5%90%EC%A0%90&ex=126.9176100&ey=37.5571229&edid=33167007',
#   'subCategory': '기타',
#   'tags': ['치킨', '순대국밥'],
#   'themes': ['모임하기 좋은', '특별한 날', '단체회식'],
#   'totalReviewCount': '7',
#   'x': '126.9176100',
#   'y': '37.5571229'},
#  {'addr': '서교동 449-43',
#   'ages': None,
#   'businessCategory': 'restaurant',
#   'businessHours': [{'day': '매일',
#                      'description': '',
#                      'endTime': '01:30',
#                      'isDayOff': False,
#                      'startTime': '11:30'}],
#   'category': '피자',
#   'commonAddr': '서울 마포구',
#   'contexts': None,
#   'description': '※흑미도우로만든 수타피자&수제크리스피치킨 전문점 강쓰키친입니다.\n'
#                  '\n'
#                  '배달비는1원도받지않습니다만!!고객님의 실수로 주소가 잘못된경우 추가비용이생길수도있습니다.\n'
#                  '\n'
#                  '★8월여름방학리뷰이벤트!!(리뷰사장님공지참조)\n'
#                  '★1000원반짝쿠폰진행중(바로결제시가능)\n'
#                  '\n'
#                  '- 피자단품 구매시 음료는 별도입니다.\n'
#                  '- M피자+사이드,  M피자+떡볶이, 치킨+떡볶이 메뉴는  음료 500ml \n'
#                  '  그 외 세트메뉴는 음료 1.25L 제공됩니다.  \n'
#                  '- 치킨주문시  캔콜라+ 지포튀김+양념소스 서비스 드립니다.\n'
#                  '-치킨에는(무+소스+캔콜라+쥐포튀김)기본제공',
#   'gender': None,
#   'id': '1679974262',
#   'imageSrc': 'http://ldb.phinf.naver.net/20180609_289/1528544754928uLtlP_JPEG/Bh8snatHPnECFlI0cBpqCQ2l.jpg',
#   'keywords': ['서교동피자', '서교동치킨', '마포구피자치킨', '마포구수타피자', '마포구수제치킨'],
#   'menus': [{'change': True,
#              'description': None,
#              'images': [],
#              'name': '1+1피자셋트L',
#              'price': '',
#              'priceType': None},
#             {'change': True,
#              'description': None,
#              'images': [],
#              'name': '1+1치킨셋트',
#              'price': '',
#              'priceType': None},
#             {'change': True,
#              'description': None,
#              'images': [],
#              'name': 'L피자+떡볶이',
#              'price': '',
#              'priceType': None},
#             {'change': True,
#              'description': None,
#              'images': [],
#              'name': '치킨+떡볶이',
#              'price': '',
#              'priceType': None}],
#   'microReviews': None,
#   'name': '강쓰키친',
#   'options': '예약,배달,포장,주차',
#   'phone': '070-7576-1747',
#   'priceCategory': '7만원 대',
#   'relatedLinks': None,
#   'roadAddr': '서울 마포구 월드컵북로5길 22',
#   'routeUrl': 'http://m.map.naver.com/viewer/route.nhn?ename=%EA%B0%95%EC%93%B0%ED%82%A4%EC%B9%9C&ex=126.9174938&ey=37.5570728&edid=1679974262',
#   'subCategory': '기타',
#   'tags': None,
#   'themes': ['데이트하기 좋은', '젊고 캐쥬얼한', '특별한 날'],
#   'totalReviewCount': '0',
#   'x': '126.9174938',
#   'y': '37.5570728'},
#  {'addr': '상수동 309-1',
#   'ages': None,
#   'businessCategory': 'restaurant',
#   'businessHours': [{'day': '매일',
#                      'description': '연중무휴.',
#                      'endTime': '24:00',
#                      'isDayOff': False,
#                      'startTime': '00:00'}],
#   'category': '감자탕',
#   'commonAddr': '서울 마포구',
#   'contexts': None,
#   'description': '',
#   'gender': None,
#   'id': '13155139',
#   'imageSrc': 'http://ldb.phinf.naver.net/20150831_217/1440996935245WdNHN_JPEG/106565493620701_0.jpg',
#   'keywords': ['감자탕전문'],
#   'menus': [{'change': False,
#              'description': None,
#              'images': [],
#              'name': '뼈다귀감자탕 소',
#              'price': '25000',
#              'priceType': None},
#             {'change': False,
#              'description': None,
#              'images': [],
#              'name': '뼈다귀감자탕 중',
#              'price': '30000',
#              'priceType': None},
#             {'change': False,
#              'description': None,
#              'images': [],
#              'name': '뼈다귀감자탕 대',
#              'price': '35000',
#              'priceType': None},
#             {'change': False,
#              'description': None,
#              'images': [],
#              'name': '물냉면',
#              'price': '5000',
#              'priceType': None},
#             {'change': False,
#              'description': None,
#              'images': [],
#              'name': '비빔냉면',
#              'price': '5000',
#              'priceType': None},
#             {'change': False,
#              'description': None,
#              'images': [],
#              'name': '해물뼈찜 소',
#              'price': '28000',
#              'priceType': None},
#             {'change': False,
#              'description': None,
#              'images': [],
#              'name': '해물뼈찜 중',
#              'price': '33000',
#              'priceType': None},
#             {'change': False,
#              'description': None,
#              'images': [],
#              'name': '해물뼈찜 대',
#              'price': '38000',
#              'priceType': None},
#             {'change': False,
#              'description': None,
#              'images': [],
#              'name': '뼈다귀해장국',
#              'price': '7000',
#              'priceType': None},
#             {'change': False,
#              'description': None,
#              'images': [],
#              'name': '양선지해장국',
#              'price': '7000',
#              'priceType': None},
#             {'change': False,
#              'description': None,
#              'images': [],
#              'name': '옛날순대국',
#              'price': '6000',
#              'priceType': None},
#             {'change': False,
#              'description': None,
#              'images': [],
#              'name': '선지해장국',
#              'price': '6000',
#              'priceType': None},
#             {'change': False,
#              'description': None,
#              'images': [],
#              'name': '돈까스',
#              'price': '6000',
#              'priceType': None}],
#   'microReviews': None,
#   'name': '주먹코감자탕해물뼈찜 상수점',
#   'options': '예약,단체석',
#   'phone': '02-322-5333',
#   'priceCategory': '2만원 대',
#   'relatedLinks': [{'name': '망고플레이트',
#                     'url': 'https://www.mangoplate.com/restaurants/Cj9ssUWmj_'},
#                    {'name': '식신', 'url': 'https://www.siksinhot.com/P/642392'},
#                    {'name': '다이닝코드',
#                     'url': 'https://diningcode.com/profile.php?rid=e3TGBxWLMn0j'}],
#   'roadAddr': '서울 마포구 독막로 95',
#   'routeUrl': 'http://m.map.naver.com/viewer/route.nhn?ename=%EC%A3%BC%EB%A8%B9%EC%BD%94%EA%B0%90%EC%9E%90%ED%83%95%ED%95%B4%EB%AC%BC%EB%BC%88%EC%B0%9C%20%EC%83%81%EC%88%98%EC%A0%90&ex=126.9241080&ey=37.5478740&edid=13155139',
#   'subCategory': '한식',
#   'tags': None,
#   'themes': [],
#   'totalReviewCount': '12',
#   'x': '126.9241080',
#   'y': '37.5478740'}]
